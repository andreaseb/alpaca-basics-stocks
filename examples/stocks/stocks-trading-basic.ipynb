# %% [markdown]
# # Alpaca-py stock trading basic

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alpacahq/alpaca-py/blob/master/examples/stocks/stocks-trading-basic.ipynb)

# %% [markdown]
# - This notebook shows how to use alpaca-py with stock trading API endpoints
# - Please use ``paper account``. Please ``DO NOT`` use this notebook with live account. In this notebook, we place orders for stocks as an example.

# %%
# Please change the following to your own PAPER api key and secret
# or set them as environment variables (ALPACA_API_KEY, ALPACA_SECRET_KEY).
# You can get them from https://alpaca.markets/
from google.colab import userdata
api_key = userdata.get('alpaca_api_key')
secret_key = userdata.get('alpaca_api_secret')

#### We use paper environment for this example ####
paper = True # Please do not modify this. This example is for paper trading only.
####

# Below are the variables for development this documents
# Please do not change these variables
trade_api_url = None
trade_api_wss = None
data_api_url = None
stream_data_wss = None

# %%
import os

if api_key is None:
    api_key = os.environ.get('ALPACA_API_KEY')

if secret_key is None:
    secret_key = os.environ.get('ALPACA_SECRET_KEY')

# %%
# install alpaca-py if it is not available
try:
    import alpaca
except ImportError:
    # !python3 -m pip install alpaca-py
    import alpaca
# Out:
# Collecting alpaca-py
#   Downloading alpaca_py-0.42.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py) (1.1.1)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py) (2.11.7)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-py) (2.32.3)
# Collecting sseclient-py<2.0.0,>=1.7.2 (from alpaca-py)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from alpaca-py) (15.0.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->alpaca-py) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->alpaca-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->alpaca-py) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->alpaca-py) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->alpaca-py) (1.17.0)
# Downloading alpaca_py-0.42.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.0/122.0 kB 1.7 MB/s eta 0:00:00
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Installing collected packages: sseclient-py, alpaca-py
# Successfully installed alpaca-py-0.42.0 sseclient-py-1.8.0

# %%
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

from alpaca.trading.client import TradingClient
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
from alpaca.data.historical.corporate_actions import CorporateActionsClient
from alpaca.data.historical.stock import StockHistoricalDataClient
from alpaca.trading.stream import TradingStream
from alpaca.data.live.stock import StockDataStream

from alpaca.data.requests import (
    CorporateActionsRequest,
    StockBarsRequest,
    StockQuotesRequest,
    StockTradesRequest,
)
from alpaca.trading.requests import (
    ClosePositionRequest,
    GetAssetsRequest,
    GetOrdersRequest,
    LimitOrderRequest,
    MarketOrderRequest,
    StopLimitOrderRequest,
    StopLossRequest,
    StopOrderRequest,
    TakeProfitRequest,
    TrailingStopOrderRequest,
)
from alpaca.trading.enums import (
    AssetExchange,
    AssetStatus,
    OrderClass,
    OrderSide,
    OrderType,
    QueryOrderStatus,
    TimeInForce,
)

# %%
# to run async code in jupyter notebook
import nest_asyncio
nest_asyncio.apply()

# %%
# check version of alpaca-py
alpaca.__version__
# Out:
# '0.42.0'

# %% [markdown]
# # Trading Client

# %%
# setup clients
trade_client = TradingClient(api_key=api_key, secret_key=secret_key, paper=paper, url_override=trade_api_url)

# %%
# check trading account
# You can check definition of each field in the following documents
# ref. https://docs.alpaca.markets/docs/account-plans
# ref. https://docs.alpaca.markets/reference/getaccount-1
acct = trade_client.get_account()
acct
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA3POUZYH4L9',
#     'accrued_fees': '0',
#     'buying_power': '200000',
#     'cash': '100000',
#     'created_at': datetime.datetime(2025, 7, 21, 18, 19, 2, 121895, tzinfo=TzInfo(UTC)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '100000',
#     'id': UUID('eacb4c6d-b707-40ef-a81e-c8d49f8bf5fe'),
#     'initial_margin': '0',
#     'last_equity': '100000',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '2',
#     'non_marginable_buying_power': '100000',
#     'options_approved_level': 3,
#     'options_buying_power': '100000',
#     'options_trading_level': 3,
#     'pattern_day_trader': False,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '100000',
#     'regt_buying_power': '200000',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '0',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %%
# check account configuration
# ref. https://docs.alpaca.markets/reference/getaccountconfig-1
acct_config = trade_client.get_account_configurations()
acct_config
# Out:
# {   'dtbp_check': <DTBPCheck.ENTRY: 'entry'>,
#     'fractional_trading': True,
#     'max_margin_multiplier': '4',
#     'max_options_trading_level': None,
#     'no_shorting': False,
#     'pdt_check': <PDTCheck.ENTRY: 'entry'>,
#     'ptp_no_exception_entry': False,
#     'suspend_trade': False,
#     'trade_confirm_email': <TradeConfirmationEmail.ALL: 'all'>}

# %%
# set account configuration
# ref. https://docs.alpaca.markets/reference/patchaccountconfig-1
req = acct_config
req.fractional_trading = not req.fractional_trading # toggle fractional trading
acct_config_new = trade_client.set_account_configurations(req)
display(acct_config_new)

# revert changes
req = acct_config_new
req.fractional_trading = not req.fractional_trading # toggle fractional trading
acct_config_reverted = trade_client.set_account_configurations(req)
display(acct_config_reverted)
# Out:
# {   'dtbp_check': <DTBPCheck.ENTRY: 'entry'>,
#     'fractional_trading': False,
#     'max_margin_multiplier': '4',
#     'max_options_trading_level': None,
#     'no_shorting': False,
#     'pdt_check': <PDTCheck.ENTRY: 'entry'>,
#     'ptp_no_exception_entry': False,
#     'suspend_trade': False,
#     'trade_confirm_email': <TradeConfirmationEmail.ALL: 'all'>}
# {   'dtbp_check': <DTBPCheck.ENTRY: 'entry'>,
#     'fractional_trading': True,
#     'max_margin_multiplier': '4',
#     'max_options_trading_level': None,
#     'no_shorting': False,
#     'pdt_check': <PDTCheck.ENTRY: 'entry'>,
#     'ptp_no_exception_entry': False,
#     'suspend_trade': False,
#     'trade_confirm_email': <TradeConfirmationEmail.ALL: 'all'>}

# %%
# get list of assets which are us_equity (default), active, and in NASDAQ
# ref. https://docs.alpaca.markets/reference/get-v2-assets-1
req = GetAssetsRequest(
  # asset_class=AssetClass.US_EQUITY,  # default asset_class is us_equity
  status=AssetStatus.ACTIVE,
  exchange=AssetExchange.NASDAQ,
)
assets = trade_client.get_all_assets(req)
assets[:2]
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('8cc7a7bb-14c3-4c1c-a887-fd772f16c671'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Oriental Rise Holdings Limited Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'ORIS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.NASDAQ: 'NASDAQ'>,
#      'fractionable': False,
#      'id': UUID('911c72cb-553f-4f48-a77d-2c82204cc3a1'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Treasure Global Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'TGL',
#      'tradable': False}]

# %% [markdown]
# ### Orders

# %%
# we will place orders which Alapca trading platform supports
# - order classes: simple, bracket, oco, oto
# - order types: market, limit, stop, stop_limit, trailing_stop
#
# please refer to the following documents for more details
# ref. https://docs.alpaca.markets/docs/orders-at-alpaca
# ref. https://docs.alpaca.markets/reference/postorder
#
# we will also use fractional trading capability of Alpaca trading platform in this example
# ref. https://docs.alpaca.markets/docs/fractional-trading

# we will place orders for symbol: SPY in this example
symbol = "SPY"

# %%
# simple, market order, fractional qty
# Alpaca trading platform support fractional trading by default
# you can specify:
# fractional qty (e.g. 0.01 qty) in the order request (which is shown in this example)
# or notional value (e.g. 100 USD) (which is in the next example)
#
# If you have an error of `qty must be integer`,
# please try to `Reset Account` of your paper account via the Alpaca Trading API dashboard
req = MarketOrderRequest(
    symbol = symbol,
    qty = 5.5,
    side = OrderSide.BUY,
    type = OrderType.MARKET,
    time_in_force = TimeInForce.DAY,
)
res = trade_client.submit_order(req)
res
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'canceled_at': None,
#     'client_order_id': 'e14a9243-63db-4f9c-b85c-cd2646fbea12',
#     'created_at': datetime.datetime(2025, 7, 21, 18, 58, 59, 880675, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 7, 21, 20, 0, tzinfo=TzInfo(UTC)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('98813ec5-5c4d-4a93-8a5e-61297aef5fe5'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#     'qty': '5.5',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 7, 21, 18, 58, 59, 880675, tzinfo=TzInfo(UTC)),
#     'symbol': 'SPY',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 7, 21, 18, 58, 59, 882377, tzinfo=TzInfo(UTC))}

# %%
# simple, market order, notional
# Alpaca trading platform support fractional trading by default
# you can specify:
# fractional qty (e.g. 0.01 qty) in the order request (which is in the example above)
# or notional value (e.g. 100 USD) (which is in this example)
req = MarketOrderRequest(
    symbol = symbol,
    notional = 1.11,  # notional is specified in USD, here we specify $1.11
    side = OrderSide.BUY,
    type = OrderType.MARKET,
    time_in_force = TimeInForce.DAY,
)
res = trade_client.submit_order(req)
res
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'canceled_at': None,
#     'client_order_id': '5fbe888a-2488-4643-a05d-7848838f2ca2',
#     'created_at': datetime.datetime(2025, 7, 21, 18, 59, 15, 647399, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 7, 21, 20, 0, tzinfo=TzInfo(UTC)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('fce507ef-2fe3-4f79-9a02-f0c1efc8c7dc'),
#     'legs': None,
#     'limit_price': None,
#     'notional': '1.11',
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#     'qty': None,
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 15, 647399, tzinfo=TzInfo(UTC)),
#     'symbol': 'SPY',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 15, 649426, tzinfo=TzInfo(UTC))}

# %%
# simple, limit order, fractional qty
req = LimitOrderRequest(
    symbol = symbol,
    qty = 0.01,
    limit_price = 550.25,
    side = OrderSide.BUY,
    type = OrderType.LIMIT,
    time_in_force = TimeInForce.DAY,
)
res = trade_client.submit_order(req)
res
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'canceled_at': None,
#     'client_order_id': '96bee807-9b8c-486a-9781-fef4c40e66e1',
#     'created_at': datetime.datetime(2025, 7, 21, 18, 59, 28, 501723, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 7, 21, 20, 0, tzinfo=TzInfo(UTC)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('1831e4f7-04f8-418d-855f-c73a9e550057'),
#     'legs': None,
#     'limit_price': '550.25',
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.LIMIT: 'limit'>,
#     'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#     'qty': '0.01',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 28, 501723, tzinfo=TzInfo(UTC)),
#     'symbol': 'SPY',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.LIMIT: 'limit'>,
#     'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 28, 502639, tzinfo=TzInfo(UTC))}

# %%
# stop order
req = StopOrderRequest(
                    symbol = symbol,
                    qty = 1,
                    side = OrderSide.BUY,
                    time_in_force = TimeInForce.GTC,
                    stop_price = 600
                    )

res = trade_client.submit_order(req)
res
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'canceled_at': None,
#     'client_order_id': 'f4dfab4a-bf6c-4249-a2ca-efa3995d0773',
#     'created_at': datetime.datetime(2025, 7, 21, 18, 59, 44, 819862, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 10, 17, 20, 0, tzinfo=TzInfo(UTC)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('edb5439c-00ad-4237-a95b-bcf8892ca49d'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.STOP: 'stop'>,
#     'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#     'qty': '1',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': '600',
#     'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 44, 819862, tzinfo=TzInfo(UTC)),
#     'symbol': 'SPY',
#     'time_in_force': <TimeInForce.GTC: 'gtc'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.STOP: 'stop'>,
#     'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 44, 820866, tzinfo=TzInfo(UTC))}

# %%
# stop limit order
req = StopLimitOrderRequest(
                    symbol = symbol,
                    qty = 1,
                    side = OrderSide.BUY,
                    time_in_force = TimeInForce.GTC,
                    limit_price = 550,
                    stop_price = 600
                    )

res = trade_client.submit_order(req)
res
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'canceled_at': None,
#     'client_order_id': '576c20ff-655c-41f0-8207-f05bd10906fc',
#     'created_at': datetime.datetime(2025, 7, 21, 18, 59, 48, 879071, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 10, 17, 20, 0, tzinfo=TzInfo(UTC)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('27203136-11d8-4381-b93e-1ee21e67854a'),
#     'legs': None,
#     'limit_price': '550',
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#     'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#     'qty': '1',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.BUY: 'buy'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': '600',
#     'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 48, 879071, tzinfo=TzInfo(UTC)),
#     'symbol': 'SPY',
#     'time_in_force': <TimeInForce.GTC: 'gtc'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#     'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 48, 880007, tzinfo=TzInfo(UTC))}

# %%
# bracket order with both stop loss and take profit
req = MarketOrderRequest(
                    symbol = symbol,
                    qty = 5,
                    side = OrderSide.BUY,
                    time_in_force = TimeInForce.DAY,
                    order_class = OrderClass.BRACKET,
                    take_profit = TakeProfitRequest(limit_price=600),
                    stop_loss = StopLossRequest(stop_price=300)
)
res = trade_client.submit_order(req)
res
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/alpaca/common/rest.py in _one_request(self, method, url, opts, retry)
#     197         try:
# --> 198             response.raise_for_status()
#     199         except HTTPError as http_error:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 422 Client Error: Unprocessable Entity for url: https://paper-api.alpaca.markets/v2/orders
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# /tmp/ipython-input-18-2833953376.py in <cell line: 0>()
#       9                     stop_loss = StopLossRequest(stop_price=300)
#      10 )
# ---> 11 res = trade_client.submit_order(req)
#      12 res
#
# /usr/local/lib/python3.11/dist-packages/alpaca/trading/client.py in submit_order(self, order_data)
#      98         """
#      99         data = order_data.to_request_fields()
# --> 100         response = self.post("/orders", data)
#     101
#     102         if self._use_raw_data:
#
# /usr/local/lib/python3.11/dist-packages/alpaca/common/rest.py in post(self, path, data)
#     238             dict: The response
#     239         """
# --> 240         return self._request("POST", path, data)
#     241
#     242     def put(self, path: str, data: Optional[dict] = None) -> dict:
#
# /usr/local/lib/python3.11/dist-packages/alpaca/common/rest.py in _request(self, method, path, data, base_url, api_version)
#     129         while retry >= 0:
#     130             try:
# --> 131                 return self._one_request(method, url, opts, retry)
#     132             except RetryException:
#     133                 time.sleep(self._retry_wait)
#
# /usr/local/lib/python3.11/dist-packages/alpaca/common/rest.py in _one_request(self, method, url, opts, retry)
#     205             error = response.text
#     206
# --> 207             raise APIError(error, http_error)
#     208
#     209         if response.text != "":
#
# APIError: {"base_price":"630.37","code":42210000,"message":"take_profit.limit_price must be \u003e= base_price + 0.01"}

# %%
# oto order with stop loss
req = LimitOrderRequest(
                    symbol = symbol,
                    qty = 1,
                    limit_price = 500,
                    side = OrderSide.BUY,
                    time_in_force = TimeInForce.DAY,
                    Class = OrderClass.OTO,
                    stop_loss = StopLossRequest(stop_price = 300)
                    )

res = trade_client.submit_order(req)
res

# %%
# oco limit order
req = LimitOrderRequest(
                    symbol = symbol,
                    qty = 1,
                    limit_price = 500,
                    side = OrderSide.BUY,
                    time_in_force = TimeInForce.DAY,
                    Class = OrderClass.OCO
                    )

res = trade_client.submit_order(req)
res

# %%
# trailing stop order
req = TrailingStopOrderRequest(
                    symbol = symbol,
                    qty = 1,
                    side = OrderSide.SELL,
                    time_in_force = TimeInForce.GTC,
                    trail_percent = 0.20 # you can also use trail_price instead of trail_percent
                    )

res = trade_client.submit_order(req)
res

# %%
# get a list of orders including closed (e.g. filled) orders by specifying symbol
req = GetOrdersRequest(
    status = QueryOrderStatus.ALL,
    symbols = [symbol]
)
orders = trade_client.get_orders(req)
orders

# %%
# see all open orders
req = GetOrdersRequest(
    status = QueryOrderStatus.OPEN,
    symbols = [symbol]
)
open_orders = trade_client.get_orders(req)
open_orders
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'canceled_at': None,
#      'client_order_id': '576c20ff-655c-41f0-8207-f05bd10906fc',
#      'created_at': datetime.datetime(2025, 7, 21, 18, 59, 48, 879071, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'expires_at': datetime.datetime(2025, 10, 17, 20, 0, tzinfo=TzInfo(UTC)),
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('27203136-11d8-4381-b93e-1ee21e67854a'),
#      'legs': None,
#      'limit_price': '550',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#      'qty': '1',
#      'ratio_qty': None,
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': '600',
#      'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 48, 883760, tzinfo=TzInfo(UTC)),
#      'symbol': 'SPY',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP_LIMIT: 'stop_limit'>,
#      'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 49, 9911, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'canceled_at': None,
#      'client_order_id': 'f4dfab4a-bf6c-4249-a2ca-efa3995d0773',
#      'created_at': datetime.datetime(2025, 7, 21, 18, 59, 44, 819862, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'expires_at': datetime.datetime(2025, 10, 17, 20, 0, tzinfo=TzInfo(UTC)),
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('edb5439c-00ad-4237-a95b-bcf8892ca49d'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP: 'stop'>,
#      'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#      'qty': '1',
#      'ratio_qty': None,
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': '600',
#      'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 44, 824896, tzinfo=TzInfo(UTC)),
#      'symbol': 'SPY',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP: 'stop'>,
#      'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 45, 159355, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'canceled_at': None,
#      'client_order_id': '96bee807-9b8c-486a-9781-fef4c40e66e1',
#      'created_at': datetime.datetime(2025, 7, 21, 18, 59, 28, 501723, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'expires_at': datetime.datetime(2025, 7, 21, 20, 0, tzinfo=TzInfo(UTC)),
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('1831e4f7-04f8-418d-855f-c73a9e550057'),
#      'legs': None,
#      'limit_price': '550.25',
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'position_intent': <PositionIntent.BUY_TO_OPEN: 'buy_to_open'>,
#      'qty': '0.01',
#      'ratio_qty': None,
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2025, 7, 21, 18, 59, 28, 501723, tzinfo=TzInfo(UTC)),
#      'symbol': 'SPY',
#      'time_in_force': <TimeInForce.DAY: 'day'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.LIMIT: 'limit'>,
#      'updated_at': datetime.datetime(2025, 7, 21, 18, 59, 28, 505204, tzinfo=TzInfo(UTC))}]

# %%
# cancel all open orders
trade_client.cancel_orders()
# Out:
# [{   'body': None,
#      'id': UUID('1831e4f7-04f8-418d-855f-c73a9e550057'),
#      'status': 200},
#  {   'body': None,
#      'id': UUID('27203136-11d8-4381-b93e-1ee21e67854a'),
#      'status': 200},
#  {   'body': None,
#      'id': UUID('edb5439c-00ad-4237-a95b-bcf8892ca49d'),
#      'status': 200}]

# %% [markdown]
# ### Positions

# %%
# get all open positions
# ref. https://docs.alpaca.markets/reference/getallopenpositions-1
positions = trade_client.get_all_positions()
positions
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'asset_marginable': True,
#      'avg_entry_price': '630.390003',
#      'avg_entry_swap_rate': None,
#      'change_today': '0.0043500430224035',
#      'cost_basis': '3468.245',
#      'current_price': '630.31',
#      'exchange': <AssetExchange.ARCA: 'ARCA'>,
#      'lastday_price': '627.58',
#      'market_value': '3467.804846',
#      'qty': '5.501744929',
#      'qty_available': '5.501744929',
#      'side': <PositionSide.LONG: 'long'>,
#      'swap_rate': None,
#      'symbol': 'SPY',
#      'unrealized_intraday_pl': '-0.440156',
#      'unrealized_intraday_plpc': '-0.0001269102960564',
#      'unrealized_pl': '-0.440154',
#      'unrealized_plpc': '-0.0001269097194691',
#      'usd': None}]

# %%
# get positions by symbol
# ref. https://docs.alpaca.markets/reference/getopenposition-1
position = trade_client.get_open_position(symbol_or_asset_id=symbol)
position
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'asset_marginable': True,
#     'avg_entry_price': '630.390003',
#     'avg_entry_swap_rate': None,
#     'change_today': '0.0043659772459288',
#     'cost_basis': '3468.245',
#     'current_price': '630.32',
#     'exchange': <AssetExchange.ARCA: 'ARCA'>,
#     'lastday_price': '627.58',
#     'market_value': '3467.859864',
#     'qty': '5.501744929',
#     'qty_available': '5.501744929',
#     'side': <PositionSide.LONG: 'long'>,
#     'swap_rate': None,
#     'symbol': 'SPY',
#     'unrealized_intraday_pl': '-0.385138',
#     'unrealized_intraday_plpc': '-0.0001110469415448',
#     'unrealized_pl': '-0.385136',
#     'unrealized_plpc': '-0.0001110463649483',
#     'usd': None}

# %%
# get positions by asset_id
trade_client.get_open_position(symbol_or_asset_id=position.asset_id)
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'asset_marginable': True,
#     'avg_entry_price': '630.390003',
#     'avg_entry_swap_rate': None,
#     'change_today': '0.0043659772459288',
#     'cost_basis': '3468.245',
#     'current_price': '630.32',
#     'exchange': <AssetExchange.ARCA: 'ARCA'>,
#     'lastday_price': '627.58',
#     'market_value': '3467.859864',
#     'qty': '5.501744929',
#     'qty_available': '5.501744929',
#     'side': <PositionSide.LONG: 'long'>,
#     'swap_rate': None,
#     'symbol': 'SPY',
#     'unrealized_intraday_pl': '-0.385138',
#     'unrealized_intraday_plpc': '-0.0001110469415448',
#     'unrealized_pl': '-0.385136',
#     'unrealized_plpc': '-0.0001110463649483',
#     'usd': None}

# %%
# close the position with specifying qty
# ref. https://docs.alpaca.markets/reference/deleteopenposition-1
trade_client.close_position(
    symbol_or_asset_id = symbol,
    close_options = ClosePositionRequest(
        qty = "0.01",
    )
)
# Out:
# {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#     'canceled_at': None,
#     'client_order_id': '224ac9c5-2d97-4651-a626-387ede1960fc',
#     'created_at': datetime.datetime(2025, 7, 21, 19, 1, 17, 794802, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'expires_at': datetime.datetime(2025, 7, 21, 20, 0, tzinfo=TzInfo(UTC)),
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('53b95ec6-0bb5-4103-9995-bc8d779d1b6e'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_CLOSE: 'sell_to_close'>,
#     'qty': '0.01',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 7, 21, 19, 1, 17, 794802, tzinfo=TzInfo(UTC)),
#     'symbol': 'SPY',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 7, 21, 19, 1, 17, 795398, tzinfo=TzInfo(UTC))}

# %% [markdown]
# # Trade Update (Stream)

# %% [markdown]
# With TradingStream client, you can get updates about trades
#
# You can open this notebook in another window and run below cell to check trade updates.

# %%
# subscribe trade updates
trade_stream_client = TradingStream(api_key, secret_key, paper=paper, url_override = trade_api_wss)

async def trade_updates_handler(data):
    print(data)

trade_stream_client.subscribe_trade_updates(trade_updates_handler)
trade_stream_client.run()

# %% [markdown]
# # Market Data (Historical)

# %%
# setup stock historical data client
stock_historical_data_client = StockHistoricalDataClient(api_key, secret_key, url_override = data_api_url)

# %%
# get historical bars by symbol
# ref. https://docs.alpaca.markets/reference/stockbars-1
now = datetime.now(ZoneInfo("America/New_York"))
req = StockBarsRequest(
    symbol_or_symbols = [symbol],
    timeframe=TimeFrame(amount = 1, unit = TimeFrameUnit.Hour), # specify timeframe
    start = now - timedelta(days = 5),                          # specify start datetime, default=the beginning of the current day.
    # end_date=None,                                        # specify end datetime, default=now
    limit = 2,                                               # specify limit
)
stock_historical_data_client.get_stock_bars(req).df
# Out:
#                                     open    high     low   close     volume  \
# symbol timestamp
# SPY    2025-07-16 20:00:00+00:00  624.18  624.23  623.63  623.81  4200866.0
#        2025-07-16 21:00:00+00:00  623.82  624.00  623.80  623.85   336841.0
#
#                                   trade_count        vwap
# symbol timestamp
# SPY    2025-07-16 20:00:00+00:00       8638.0  624.050318
#        2025-07-16 21:00:00+00:00       1302.0  623.931714

# %%
# get historical trades by symbol
req = StockTradesRequest(
    symbol_or_symbols = [symbol],
    start = now - timedelta(days = 5),                          # specify start datetime, default=the beginning of the current day.
    # end=None,                                             # specify end datetime, default=now
    limit = 2,                                                # specify limit
)
stock_historical_data_client.get_stock_trades(req).df
# Out:
#                                         exchange    price  size  \
# symbol timestamp
# SPY    2025-07-16 19:01:46.731434+00:00        D  624.485  30.0
#        2025-07-16 19:01:46.744548+00:00        D  624.490  25.0
#
#                                                      id conditions tape
# symbol timestamp
# SPY    2025-07-16 19:01:46.731434+00:00  52983609182281     [ , I]    B
#        2025-07-16 19:01:46.744548+00:00  71714584151603     [ , I]    B

# %%
# get historical quotes by symbol
req = StockQuotesRequest(
    symbol_or_symbols = [symbol],
    start = now - timedelta(days = 5),                      # specify start datetime, default=the beginning of the current day.
    # end=None,                                             # specify end datetime, default=now
    limit = 2,                                              # specify limit
)
stock_historical_data_client.get_stock_quotes(req).df

# %%
# get latest quotes by symbol
req = StockQuotesRequest(
    symbol_or_symbols = [symbol],
)
res = stock_historical_data_client.get_stock_latest_quote(req)
res

# %% [markdown]
# # Market Data (Stream)

# %%
stock_data_stream_client = StockDataStream(api_key, secret_key, url_override = stream_data_wss)

async def stock_data_stream_handler(data):
    print(data)

symbols = [symbol]

stock_data_stream_client.subscribe_quotes(stock_data_stream_handler, *symbols)
stock_data_stream_client.subscribe_trades(stock_data_stream_handler, *symbols)

stock_data_stream_client.run()
# Out:
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 351804, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 352471, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 352606, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=6.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 353804, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 355042, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 359237, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 360926, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 380813, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 381254, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 381810, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 381931, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 381976, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 382011, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 382051, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 382091, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 382292, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 900980, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 901175, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 910582, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 951480, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 14, 968425, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 8365, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 19767, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 19812, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 19842, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 19857, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 45588, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 46751, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 115790, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 115810, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 160963, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 174189, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 415543, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 435861, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 445309, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 445760, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 555436, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 656220, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 656696, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 669602, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 669858, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 669858, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 670193, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 679069, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 679115, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 679546, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 679671, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 681550, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 682037, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 688557, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 727054, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 727089, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 757220, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 774827, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 878017, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 878053, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 878178, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 889610, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 889610, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 15, 889660, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 35141, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 78043, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 87125, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 87235, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 87285, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 141263, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 141263, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 141624, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 184271, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 188641, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 353719, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 365396, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 545981, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546006, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.15 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546051, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=4.0 bid_exchange='V' ask_price=630.15 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546066, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=5.0 bid_exchange='V' ask_price=630.15 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546237, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=6.0 bid_exchange='V' ask_price=630.15 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546582, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=6.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546823, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=5.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 546943, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=6.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 547835, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=5.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 548637, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=4.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 549634, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 554200, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 554321, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=1.0 bid_exchange='V' ask_price=630.15 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 554501, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=1.0 bid_exchange='V' ask_price=630.16 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 554962, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=2.0 bid_exchange='V' ask_price=630.16 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 555348, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=1.0 bid_exchange='V' ask_price=630.16 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 555478, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 555724, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 555899, tzinfo=datetime.timezone.utc) bid_price=630.13 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556256, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=4.0 bid_exchange='V' ask_price=630.14 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556441, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556641, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556761, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556872, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556897, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 556962, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 557177, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 557468, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=5.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 557618, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 557664, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 557959, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 558135, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.14 ask_size=5.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 558160, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=5.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 558691, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 560024, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 560400, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 560400, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 566434, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 693807, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 739446, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 739817, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 739897, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 16, 750502, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 112478, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 112483, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 112483, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 112523, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 112859, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 113014, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 113300, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 124827, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 139707, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 139712, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 176996, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 237164, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 244702, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 244862, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 244973, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 244998, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 245008, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 245273, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 245770, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 254345, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 294916, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 319650, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 320788, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 321069, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 321149, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 321249, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 321279, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 321284, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 321304, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 328211, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 434769, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 434839, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 434904, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 434924, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 436724, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 439686, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 439966, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 776356, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 776957, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 788360, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 788520, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 17, 798043, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 14788, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 14793, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 14833, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 15264, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 352295, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 352546, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 352867, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 392175, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 652133, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 652218, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 652218, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 652679, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 659526, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 756115, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 851126, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 18, 868352, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 20003, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 97798, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 97798, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 97853, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.14 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 97898, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 97898, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 98229, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 98279, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 99211, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=6.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 100008, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=5.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 101416, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=4.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 101421, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=3.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 101977, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 107390, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 120461, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 120501, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 318577, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 475345, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 798333, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 798890, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 970042, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 970112, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 970628, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 19, 977830, tzinfo=datetime.timezone.utc) bid_price=630.12 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 4985, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 14683, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 212319, tzinfo=datetime.timezone.utc) exchange='V' price=630.125 size=10.0 id=52983746474598 conditions=[' ', 'I'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221615, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221630, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221650, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221700, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221815, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.13 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221830, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 221925, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 222191, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 222382, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 224872, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 224897, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.13 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 225469, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=2.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 226652, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 227564, tzinfo=datetime.timezone.utc) bid_price=630.11 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 20, 227674, tzinfo=datetime.timezone.utc) bid_price=630.1 bid_size=1.0 bid_exchange='V' ask_price=630.12 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# ...
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 39670, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 41960, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 42101, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 50014, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 58064, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 94836, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=3.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 154543, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 214881, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 253563, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 378135, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 394163, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 406627, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 488167, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 530818, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 538862, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 544425, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 595166, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 631372, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 640143, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 654677, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 655068, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 683716, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 948140, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 948511, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 23, 976813, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 60276, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 124183, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 124259, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=4.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 124519, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 125076, tzinfo=datetime.timezone.utc) bid_price=630.04 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 125161, tzinfo=datetime.timezone.utc) bid_price=630.04 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 125381, tzinfo=datetime.timezone.utc) bid_price=630.04 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 125582, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 126298, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 126534, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 128659, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 213170, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 223169, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 256247, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 277377, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 521302, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 521548, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 542753, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.07 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 542994, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 543275, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 584167, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 584407, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 608896, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.07 ask_size=1.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 609016, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 644691, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=3.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 644711, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=4.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 644851, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=4.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 645112, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=3.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 645182, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=4.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 645868, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=5.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 648615, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=4.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 648615, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=3.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 648615, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 654755, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 670367, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 844731, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 845293, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 859602, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=3.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 24, 880146, tzinfo=datetime.timezone.utc) bid_price=630.07 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 25, 17006, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=2.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# symbol='SPY' timestamp=datetime.datetime(2025, 7, 21, 19, 2, 25, 17432, tzinfo=datetime.timezone.utc) bid_price=630.06 bid_size=1.0 bid_exchange='V' ask_price=630.08 ask_size=2.0 ask_exchange='V' conditions=['R'] tape='B'
# keyboard interrupt, bye
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /tmp/ipython-input-28-4188646833.py in <cell line: 0>()
#       9 stock_data_stream_client.subscribe_trades(stock_data_stream_handler, *symbols)
#      10
# ---> 11 stock_data_stream_client.run()
#
# /usr/local/lib/python3.11/dist-packages/alpaca/data/live/websocket.py in run(self)
#     369             pass
#     370         finally:
# --> 371             self.stop()
#     372
#     373     def stop(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/alpaca/data/live/websocket.py in stop(self)
#     374         """Stops the websocket connection."""
#     375         if self._loop.is_running():
# --> 376             asyncio.run_coroutine_threadsafe(self.stop_ws(), self._loop).result(
#     377                 timeout=5
#     378             )
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     456                     return self.__get_result()
#     457                 else:
# --> 458                     raise TimeoutError()
#     459         finally:
#     460             # Break a reference cycle with the exception in self._exception
#
# TimeoutError:

# %% [markdown]
# # Corporate actions

# %%
corporate_actions_client = CorporateActionsClient(api_key, secret_key)
corporate_actions_client.get_corporate_actions(CorporateActionsRequest(
    start=datetime(2020, 1, 1),
    symbols=[symbol]
)).df
# Out:
#                                                          id symbol      cusip  \
# corporate_action_type
# cash_dividends         e06f1a82-04b5-4b90-9c7b-06d22b720db1    SPY  78462F103
# cash_dividends         a6587d80-e08a-4b1a-aa94-857549880c59    SPY  78462F103
# cash_dividends         ffb8940e-53fe-4b3e-a475-e15e39561d3d    SPY  78462F103
# cash_dividends         4d35e709-773b-46d4-b292-34d14c46f287    SPY  78462F103
# cash_dividends         f1ddda1e-b10c-4576-8253-4d8d5a149de6    SPY  78462F103
# cash_dividends         a06ac608-4210-4e4f-94f0-4fa342a8e1fd    SPY  78462F103
# cash_dividends         d2b09118-e4c0-4b93-9f46-10b211400773    SPY  78462F103
# cash_dividends         7cdc9442-1a32-4f40-9d2a-b721edfef9e9    SPY  78462F103
# cash_dividends         f5ca31fd-da0d-4651-be6b-6ac78542259e    SPY  78462F103
# cash_dividends         1f5b9849-96be-4d48-8c3a-b383dc2c544c    SPY  78462F103
# cash_dividends         377f7022-91cc-44da-9a8e-8bb00083d5a5    SPY  78462F103
# cash_dividends         0451d145-f55a-482f-9e11-8dad5910a801    SPY  78462F103
# cash_dividends         4bedbc95-3ce2-40fb-9a38-7d08717a69fc    SPY  78462F103
# cash_dividends         bbbff9be-c5e0-467e-87e0-396b636388b7    SPY  78462F103
# cash_dividends         774bf420-19e4-4ac1-b8b6-39e170496bd1    SPY  78462F103
# cash_dividends         0b715f27-57cc-4e72-975f-800ac009ecbd    SPY  78462F103
# cash_dividends         1788732d-92bc-47ba-89c8-dc3435a09b2a    SPY  78462F103
# cash_dividends         1eedcf06-a75b-4559-8215-2874546d6b80    SPY  78462F103
# cash_dividends         0429797e-504e-4571-855d-55d29cdb63d9    SPY  78462F103
# cash_dividends         24d33e88-e83b-467b-9832-821d2a97d4a5    SPY  78462F103
# cash_dividends         ed10c000-8a0b-44ba-a9d7-15f455b61d7a    SPY  78462F103
#
#                            rate  special  foreign process_date     ex_date  \
# corporate_action_type
# cash_dividends         1.405559    False    False   2020-04-30  2020-03-20
# cash_dividends         1.366242    False    False   2020-07-31  2020-06-19
# cash_dividends         1.339224    False    False   2020-10-30  2020-09-18
# cash_dividends         1.580000    False    False   2021-01-29  2020-12-18
# cash_dividends         1.277788    False    False   2021-04-30  2021-03-19
# cash_dividends         1.375875    False    False   2021-07-30  2021-06-18
# cash_dividends         1.428117    False    False   2021-10-29  2021-09-17
# cash_dividends         1.636431    False    False   2022-01-31  2021-12-17
# cash_dividends         1.366009    False    False   2022-04-29  2022-03-18
# cash_dividends         1.576871    False    False   2022-07-29  2022-06-17
# cash_dividends         1.596398    False    False   2022-10-31  2022-09-16
# cash_dividends         1.781400    False    False   2023-01-31  2022-12-16
# cash_dividends         1.506204    False    False   2023-04-28  2023-03-17
# cash_dividends         1.638367    False    False   2023-07-31  2023-06-16
# cash_dividends         1.583169    False    False   2023-10-31  2023-09-15
# cash_dividends         1.906073    False    False   2024-01-31  2023-12-15
# cash_dividends         1.594937    False    False   2024-04-30  2024-03-15
# cash_dividends         1.759024    False    False   2024-07-31  2024-06-21
# cash_dividends         1.745531    False    False   2024-10-31  2024-09-20
# cash_dividends         1.965548    False    False   2025-01-31  2024-12-20
# cash_dividends         1.695528    False    False   2025-04-30  2025-03-21
#
#                       record_date payable_date
# corporate_action_type
# cash_dividends         2020-03-23   2020-04-30
# cash_dividends         2020-06-22   2020-07-31
# cash_dividends         2020-09-21   2020-10-30
# cash_dividends         2020-12-21   2021-01-29
# cash_dividends         2021-03-22   2021-04-30
# cash_dividends         2021-06-21   2021-07-30
# cash_dividends         2021-09-20   2021-10-29
# cash_dividends         2021-12-20   2022-01-31
# cash_dividends         2022-03-21   2022-04-29
# cash_dividends         2022-06-21   2022-07-29
# cash_dividends         2022-09-19   2022-10-31
# cash_dividends         2022-12-19   2023-01-31
# cash_dividends         2023-03-20   2023-04-28
# cash_dividends         2023-06-20   2023-07-31
# cash_dividends         2023-09-18   2023-10-31
# cash_dividends         2023-12-18   2024-01-31
# cash_dividends         2024-03-18   2024-04-30
# cash_dividends         2024-06-21   2024-07-31
# cash_dividends         2024-09-20   2024-10-31
# cash_dividends         2024-12-20   2025-01-31
# cash_dividends         2025-03-21   2025-04-30
